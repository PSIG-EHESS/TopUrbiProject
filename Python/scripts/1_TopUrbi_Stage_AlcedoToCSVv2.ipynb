# %%
#Script pour traiter les entrées de lieux les plus repandues qui commencent par le nom de lieu tout en majuscule, par exemple :
# ZIPAQUIRA, Pueblo y Cabeza de partido del Corregimiento de su nombre en el Nuevo Reyno de Granada, es de temperamento frío, pero benigno y sano, situado en una hermosa y agradable llanura, produce con abundancia trigo, maiz, cebada, papas y legumbres, que vende para las demás Provincias, con lo que hace un lucroso comercio en el mercado que celebra cada cinco dias, tiene unas abundantísimas salinas de que saca 20.000 fanegas de sal cada año, su vecindario se compone de mas de 800 vecinos y 80 Indios, fue doctrina de los Religiosos de San Francisco; está 4 leguas al N de Santa Fé. 
# TODO : à traiter les entrées de mots composés, comme par exemple :
# ZELANDA, Nueva) Villa y fuerte de los Holandeses en la Provincia y Colonia de Surinam, situada á la orilla del rio Poumaron en el cabo ó punta de Nassau ó Orange. 

# ça prends presque toutes les varietés des noms composés ^ *[A-Z|Ñ|-]+(\s|\.|,|:|\))+([A-Z|a-z|é|í|ñ|.| ]+) "space c'est optionnel"


from lxml import etree
import csv
import glob
import re
from lxml import html
from bs4 import BeautifulSoup

ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

def clean_text(entry):
    "Function used to remove blank new lines"
    entry = entry.replace("\n", "")
    entry = re.sub('\s{2,}', ' ', entry)
    return entry

def get_div(doc):
    data = []
    root = doc.getroot()
    for child in root:
      #print(child.tag, child.attrib)
      for cchild in child:
        #print(cchild)
        for ccchild in cchild:
          #print(ccchild.tag)
          if ccchild.tag == "{http://www.tei-c.org/ns/1.0}div":
            #print(ccchild.text)
            data.append(ccchild)
    return data 

# recupere tous les noms de lieu en maj

def detection_LieuCompose(line):
  # testé sur le site : [A-Z|Ñ|-]+(\s|\.|,|:|\))+([A-Z|a-z|é|í|ñ|.| ]+)
  # old :  ([A-Z|Ñ|-]+(\s|\.|,|:|\))+([A-Z|a-z|é|í|ñ|.| ]+))
  match = re.search(r'^ [A-Z|Ñ|-]+(\s|\.|,|:|\))+([A-Z|a-z|é|í|ñ|.| ]+\))', line, re.DOTALL|re.MULTILINE) #TODO cas particuliers à gérer : 1) "San Bernardo" 2) "ZAND, Puente de)"
  if match:
    return match.group(0)

def detection_nomLieu(line):
  match = re.search(r' ([A-Z|Ñ|-]*)', line, re.DOTALL|re.MULTILINE) #TODO cas particuliers à gérer : 1) "San Bernardo" 2) "ZAND, Puente de)"
  if match:
    return match.group(1)

        
# attrape le type de lieu après le nom en majusc; ex: Pueblo, etc.

def detection_nomLieu_general(line):
  nomcomp = detection_LieuCompose(line)
  #print("lieu compo : "+str(nomcomp))
  if (nomcomp is not None):
    return nomcomp
  else:
    return detection_nomLieu(line)
    
def detection_typeLieu(line):
  match = re.search(r' [A-Z|Ñ|-|À-Ÿ]+(\s|\.|,|:|\))+([A-Z_À-Ÿ][a-z_à-ÿ]+)', line, re.DOTALL|re.MULTILINE) #TODO cas particuliers à gérer : 1) "San Bernardo" 2) "ZAND, Puente de)"
  if match: #regex à vérifier 
    return match.group(2)


#Prends tout le texte dans div

def detection_descLieu(div):
  node = etree.strip_tags(div,'*')
  return div.text


def detection_listLieu(div):
  div_str = etree.tostring(div)
  soup = BeautifulSoup(div_str, "lxml")
  list_tag = [] 
  for j in soup.div.find_all(recursive=False):
    list_tag.append(j)
  #print(list_tag)
  return list_tag


# Prends tous les id's

def detection_entreeLieuID(div):
  div_str = etree.tostring(div)
  soup = BeautifulSoup(div_str, "lxml")
  return soup.div['xml:id']

# Prends tous les settlement's

def detection_settlement(div):
  div_str = etree.tostring(div)
  soup = BeautifulSoup(div_str, "lxml")
  if soup.div.get('settlement'):
    return soup.div['settlement']

## MAIN
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
alcedo_xml = "/content/drive/MyDrive/Colab Notebooks/data/Alcedo/1_Alcedo_XML_Origine"
alcedo_csv = "/content/drive/MyDrive/Colab Notebooks/data/Alcedo/2_Alcedo_conversion_CSV"
if __name__ == "__main__":
    for tome in [1, 2, 3, 4, 5]:
        print(tome)
        with open(alcedo_csv+"/alcedo_tome"+str(tome)+"utf-8.csv", 'w+', newline='', encoding="utf-8") as csvfile:
          parser = etree.XMLParser(remove_blank_text=True)
          doc = etree.parse(alcedo_xml+"/alcedo-"+str(tome)+"-utf8.xml", parser)
          data = get_div(doc)
          writer = csv.writer(csvfile, delimiter='|')
          writer.writerow(['id_lieu','nom_lieu', 'settlement', 'desc_lieu', 'type_lieu', 'list_lieu', 'level1', 'level2'])
          tome = tome + 1
          for div in data:

            level1, level2 = [], []
            for child in div:
              print("level1: "+str(child.tag))
              print("level1: "+str(child.text))
              level1.append(str(child.text) + "|" + str(child.tag) + "|" + str(child.attrib))
              for cchild in child:
                print("level2: "+str(cchild.tag))
                print("level2: "+str(cchild.text)) 
                level2.append(str(cchild.text) + "|" + str(cchild.tag) + "|" + str(cchild.attrib))
                print("")

            list_lieu = detection_listLieu(div)
           
            div_id = detection_entreeLieuID(div)
           
            settlement = detection_settlement(div)
           
            desc_lieu = detection_descLieu(div)
           
            #lieu_compose = detection_LieuCompose(desc_lieu)
            #if (lieu_compose is not None):
            #  print("LIEU COMPOSE: " + str(lieu_compose))
            #nom_lieu = detection_nomLieu(desc_lieu)
            #print("nom_lieu:" + str(nom_lieu))
            nom_lieu = detection_nomLieu_general(desc_lieu)
           
            type_lieu = detection_typeLieu(desc_lieu)
           
            writer.writerow([div_id, nom_lieu, settlement, desc_lieu, type_lieu, str(list_lieu), level1, level2])

#Entrée type à traiter dans un autre script, les cas des entrées homonymes, un exemple :
# Otro Pueblo hay de este nombre en la Cabeza de partido de Huipuxla, y Alcaldía mayor de Tepetango  en Nueva España, tiene 53 familias de Indios. 
# Cependant ils sont déjà récupérés dans les div's
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento del
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Conchucos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chiapa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Venezuela
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Venezuela
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chachapoyas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Caxatambo
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Pais de las Amazonas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Cuenca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Pais de las Amazonas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Riobamba
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Jaén de Bracamoros
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Luisiana
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Pastos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Moxos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Pais de las Amazonas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tucuman
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Isla de Cuba
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cartagena
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Camaná
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chaco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tucuman
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Caxamarca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Darien
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Huarochiri
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chilques y Masques
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Cuernavaca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nexapa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Canta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Mainas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chaco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Maule
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Antioquía
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tepetango
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Nueva Vizcaya
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Coquimbo
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Arica
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Buenos Ayres
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Guauchinango
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Porco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Larecaja
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Cuenca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Guayana ó Nueva Andalucia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  los Indios Chiquitos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Octiupa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tepozcolula
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Obispado de Oaxaca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Quillota
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Cuquio
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Yamparaes
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Luisiana
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  el Tucumán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cartagena
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Santa Marta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Vera Paz
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Nueva Galicia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Nueva Galicia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chancay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nochiztlán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Villalta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Buenos Ayres
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Loxa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Itata
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Popayan
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tepozcolula
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Conchucos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Huailas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chancay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Omasuyos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Chucuito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tucumán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Conchucos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cumaná
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Quixos y Macas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Collahuas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Santa Cruz de la Sierra
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Guayana
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chancay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Guayana ó Nueva Andalucía
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Pomabamba
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Zelaya
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Obispado de Mechoacan
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Chachapoyas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Guayana ó Nueva Andalucía
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Maule
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cuenca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Guayana
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Antioquia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chilapa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Autlán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Valladolid
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Obispado de Mechoacan
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: San Juan de los Llanos
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Azuchitlán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Chucuito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Nueva Galicia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Nueva Vizcaya
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Tezcoco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Xicayán
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Obispado de Mechoacan
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: None
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Cuernavaca
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Colima
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Quatro Villas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Parinacochas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cartagena
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Cartagena
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Obispado de Mechoacan
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Jaén de Bracamoros
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Maracaibo
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chaco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chaco
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Quispicanchi
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Vilcas Huaman
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Truxillo
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Zamora
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Mainas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Venezuela
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  la Sonora
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Pasto
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Chiapa
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Costarica
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Corregimiento de Sicasica
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Venezuela
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Maracaibo
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Mainas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Santa Marta
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Gobierno
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2:  Antioquia
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# ...
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Pasto
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Buenos Ayres
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Alcaldía mayor
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Huamelula
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}roleName
# level2: Provincia
#
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Pais de las Amazonas
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Guayaquil
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Provincia del Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: California
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Quito
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Chile
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Provincia del Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Provincia del Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno de Guatemala
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Reyno del Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Provincia del Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Provincia del Paraguay
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nueva España
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: Nuevo Reyno de Granada
#
# level1: {http://www.tei-c.org/ns/1.0}placeName
# level1: None
# level2: {http://www.tei-c.org/ns/1.0}district
# level2: el Perú

# %% [markdown]
# A la fin de ce traitement, les tomes en CSV ont été séparés chacun si applicable en deux, l'une pour le contenu principal du tome et l'autre pour les annexes.
