# %%
import csv
import pandas as pd

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
alcedo_dossier = "/content/drive/MyDrive/Colab Notebooks/data/Alcedo/3a_Alcedo_CSV_principal"
# ce traitement ne se fait pas sur les annexes des tomes car cela implique traiter des doublons et donc avoir des identifiants en doublon. 

# Pour lire le fichier csv
tome = 1
df_list = []
for file_name in [1, 2, 3, 4, 5]:
  print("tome: "+str(file_name))
  Alcedo_df = pd.read_csv(alcedo_dossier + '/alcedo_tome'+str(tome)+'_principal_utf-8.csv', delimiter='|', index_col=0)
  
  
  # Attraper les entrees sans settlement
  entrees_sans_settlement = Alcedo_df[Alcedo_df['settlement'].isnull()]
  print("entrees_sans_settlement: "+str(len(entrees_sans_settlement)))
  
  # Filtrer avec les type_lieu
  lieux_sans_settlement_types = entrees_sans_settlement.loc[entrees_sans_settlement['type_lieu' ].isin(["Pueblo","Nación", "Provincia", "Isla", "Ciudad", "Alcaldía"])] 
  #display(entrees_sans_settlement['nom_lieu'])
  #.isin([3, 6])
  print("lieux_sans_settlement_types: "+str(len(lieux_sans_settlement_types)))

  #ajout colonne normalisée nom de lieu
  lieux_sans_settlement_types['placename'] = lieux_sans_settlement_types.apply(lambda row: str(row.nom_lieu).lower(), axis=1)

  #dataframe.loc[dataframe['Percentage'] > 80]
  #display(lieux_sans_settlement_types)
  #print("lieux_sans_settlement_types: "+str(len(lieux_sans_settlement_types.columns)))

  lieux_sans_settlement_types_f = lieux_sans_settlement_types.drop("settlement", axis=1)
  #fusionner les df
  df_list.append(lieux_sans_settlement_types_f)
  tome = tome + 1

  #Fusionner tous les tomes du dictionaire dans un seule fichier.
  
df_total = pd.concat(df_list)
df_total.to_csv('/content/drive/MyDrive/Colab Notebooks/data/Alcedo/alcedo_all_vol_filtered.csv')
  
print("df_total: "+str(len(df_total)))
#display(df_total)

#vérifier des doublons dans une colonne
#lieux_sans_settlement_types.placename.duplicated()
# Out:
# Mounted at /content/drive
# tome: 1
# entrees_sans_settlement: 5188
# lieux_sans_settlement_types: 1846
# tome: 2
# entrees_sans_settlement: 3839
# lieux_sans_settlement_types: 1164
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# tome: 3
# entrees_sans_settlement: 2427
# lieux_sans_settlement_types: 808
# tome: 4
# entrees_sans_settlement: 3515
# lieux_sans_settlement_types: 1186
# tome: 5
# entrees_sans_settlement: 2849
# lieux_sans_settlement_types: 1248
# df_total: 6252

# %%
topurbi_dossier2 = "/content/drive/MyDrive/Colab Notebooks/data/Alcedo"

# Lire le gazetiers HGIS de las Indias
hgis_df = pd.read_excel(topurbi_dossier2 + '/HGIS_Indias_lugares_id.xlsx', index_col=0)  

hgis_df['placename'] = hgis_df.apply(lambda row: str(row.label).lower(), axis=1)

cols= ['check', 'template', 'wikitext1', 'wikitext2', 'wikitext'] 
#version allegée pour lisibilité mais à reténir pour la désambiguisation
hgis_df_f = hgis_df.drop(cols, axis=1) 
display(hgis_df_f)
#display(hgis_df['nombre'])
#display(hgis_df['variantes'])
# Out:
#                   label          nombre                        variantes  \
# gz_id
# 101010              [-]             [-]                              [-]
# 1000000             [-]             [-]                              [-]
# 1000001          Mexico          Mexico                              NaN
# 1000002     Guadalajara     Guadalajara                              NaN
# 1000003       Chihuahua       Chihuahua              San Felipe el Real|
# ...                 ...             ...                              ...
# 9901273         Guyciri             NaN          Guisiri|Huisiri|Vyisiri
# 9901274    San Salvador             NaN            San Salvador Urinamas
# 9901275  Tierra Adentro  Tierra Adentro                         Chirripo
# 9901276         Guicasi             NaN  Guicazi|Guicaci|Guycasi|Guycazi
# 9901277         Monimbo             NaN                              NaN
#
#                 nombrehoy  categoria partido_generico provincia_generica  \
# gz_id
# 101010                [-]        [-]              NaN                NaN
# 1000000               [-]        [-]              NaN                NaN
# 1000001  Ciudad de Mexico     Ciudad           Mexico             Mexico
# 1000002       Guadalajara     Ciudad      Guadalajara        Guadalajara
# 1000003         Chihuahua  Poblacion        Chihuahua            Durango
# ...                   ...        ...              ...                ...
# 9901273               NaN     Pueblo         Chirripo         Costa Rica
# 9901274               NaN     Pueblo         Chirripo         Costa Rica
# 9901275               NaN     Fuerte         Chirripo         Costa Rica
# 9901276               NaN     Pueblo       Costa Rica         Costa Rica
# 9901277               NaN     Pueblo          Granada          Nicaragua
#
#         region pais        lat         lon      fuente_ID  fundacion  \
# gz_id
# 101010     NaN  NaN  90.000000    0.000000    desconocida     1111.0
# 1000000    NaN  NaN  90.000000    0.000000    desconocida     1111.0
# 1000001    NES  MEX  19.433786  -99.133134      gerhardNE     1521.0
# 1000002    GDJ  MEX  20.676143 -103.346998  gerhard-north     1532.0
# 1000003    GDJ  MEX  28.654323 -106.083947  gerhard-north     1708.0
# ...        ...  ...        ...         ...            ...        ...
# 9901273    GUA  CRC        NaN         NaN           wiki        NaN
# 9901274    GUA  CRC        NaN         NaN           wiki        NaN
# 9901275    GUA  CRC        NaN         NaN           wiki        NaN
# 9901276    GUA  CRC        NaN         NaN           wiki        NaN
# 9901277    GUA  NIC        NaN         NaN           wiki        NaN
#
#               placename
# gz_id
# 101010              [-]
# 1000000             [-]
# 1000001          mexico
# 1000002     guadalajara
# 1000003       chihuahua
# ...                 ...
# 9901273         guyciri
# 9901274    san salvador
# 9901275  tierra adentro
# 9901276         guicasi
# 9901277         monimbo
#
# [13405 rows x 14 columns]

# %%
from google.colab import data_table

#data_table.enable_dataframe_formatter()

result_join_num1 = pd.merge(df_total, hgis_df_f[pd.notnull(hgis_df.placename)], on="placename", how="inner")

#data_table.DataTable(result_join_num1, include_index=False, num_rows_per_page=10)

display(result_join_num1)
result_join_num1.to_csv('/content/drive/MyDrive/Colab Notebooks/data/Alcedo/jointureAlcedo_HGISIndias.csv')


#foo.merge(bar[pd.notnull(bar.id)], how='left', on='id')

###result_join_num1.to_csv('/content/drive/MyDrive/Colab Notebooks/data/Alcedo/jointure_Alcedo_HGIS', sep='|')


# Trouver les colonnes avec des données manquantes

# hgis_df.isnull().any(axis=1)

# axis 1 = par colonne
# axis 0 =  par ligne

# Nombre de données manquantes par colonnes

###result_join_num1.isnull().sum()

# Pour supprimer on peut faire un drop

# Faire un to_numeric dans la colonne qu'on veut, pour transformer en une colonne en numero, mettre le paramettre errors = "coerce", que veut dire en cas d'error, laisse vide.

# Où juste changer les Nan par "-"
# Out:
#           nom_lieu                                          desc_lieu  \
# 0          ABANCAY   ABANCAY, Provincia y Corregimiento del Perú, ...
# 1          ABUCARA  \n ABUCARA, Pueblo de la Provincia y Corregimi...
# 2     ACAMUCHITLAN  \n ACAMUCHITLAN, Pueblo de la Cabecera de Part...
# 3            ACARI  \n ACARI, Pueblo de la Provincia y Corregimien...
# 4         ACARIGUA  \n ACARIGUA,Pueblo de la Provincia y Gobierno ...
# ...            ...                                                ...
# 2632      ZOYATLAN  \n ZOYATLAN, Pueblo de la Cabeza de partido y ...
# 2633      ZOYATLAN  \n ZOYATLAN, Pueblo de la Cabeza de partido y ...
# 2634   ZUMPAHUACAN  \n ZUMPAHUACAN, Pueblo y Cabeza de partido de ...
# 2635        ZUÑIGA  \n ZUÑIGA, Pueblo de la Provincia y Corregimie...
# 2636        ZUÑIGA  \n ZUÑIGA, Pueblo de la Provincia y Corregimie...
#
#       type_lieu                                          list_lieu  \
# 0     Provincia  [<placename><district key="JUPEHUAH">Andahuail...
# 1        Pueblo  [<placename><rolename type="province">Provinci...
# 2        Pueblo  [<placename><district key="JUNEMXTE"><placenam...
# 3        Pueblo  [<placename><rolename type="province">Provinci...
# 4        Pueblo  [<placename><rolename type="province">Provinci...
# ...         ...                                                ...
# 2632     Pueblo  [<placename><rolename type="alcaldia_mayor">Al...
# 2633     Pueblo  [<placename><rolename type="alcaldia_mayor">Al...
# 2634     Pueblo  [<placename><rolename type="alcaldia_mayor">Al...
# 2635     Pueblo  [<placename><rolename type="province">Provinci...
# 2636     Pueblo  [<placename><rolename type="province">Provinci...
#
#          placename         label                    nombre variantes  \
# 0          abancay       Abancay                   Abancay       NaN
# 1          abucara       Abucara                   Abucara       NaN
# 2     acamuchitlan  Acamuchitlan     San Juan Acamuchitlan       NaN
# 3            acari         Acari                     Acari       NaN
# 4         acarigua      Acarigua       San Miguel Acarigua       NaN
# ...            ...           ...                       ...       ...
# 2632      zoyatlan      Zoyatlan                  Zoyatlan       NaN
# 2633      zoyatlan      Zoyatlan      San Nicolas Zoyatlan       NaN
# 2634   zumpahuacan   Zumpahuacan      Asuncion Zumpahuacan       NaN
# 2635        zuñiga        Zuñiga  Espiritu Santo de Zuniga   Zuñiga|
# 2636        zuñiga        Zuñiga                    Zuñiga       NaN
#
#      nombrehoy categoria partido_generico provincia_generica region pais  \
# 0          NaN     Villa          Abancay              Cuzco    PER  PER
# 1       Aucara    Pueblo          Lucanas           Huamanga    PER  PER
# 2          NaN    Pueblo    Temascaltepec             Mexico    NES  MEX
# 3          NaN    Pueblo           Camana           Arequipa    PER  PER
# 4          NaN    Pueblo           Araure            Caracas    VEN  VEN
# ...        ...       ...              ...                ...    ...  ...
# 2632       NaN    Pueblo            Tlapa             Puebla    NES  MEX
# 2633       NaN    Pueblo            Tlapa             Puebla    NES  MEX
# 2634       NaN    Pueblo        Malinalco             Mexico    NES  MEX
# 2635       NaN    Pueblo            Texas              Texas    GDJ  USA
# 2636       NaN    Pueblo           Cañete               Lima    PER  PER
#
#             lat         lon   fuente_ID  fundacion
# 0    -13.633350  -72.883308     vollmer     1574.0
# 1    -14.280607  -73.976538     vollmer     1111.0
# 2     18.836111 -100.267500       tanck     1111.0
# 3    -15.433901  -74.617011     vollmer     1111.0
# 4      9.559800  -69.193760  relgeo-ven     1111.0
# ...         ...         ...         ...        ...
# 2632  17.323611  -98.366667       tanck     1111.0
# 2633  16.709444  -98.738056       tanck     1111.0
# 2634  18.836389  -99.578611       tanck     1111.0
# 2635  28.667500  -97.346500    missions     1722.0
# 2636 -12.859669  -76.023234     vollmer     1111.0
#
# [2637 rows x 18 columns]

# %%
display(result_join_num1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1710 entries, 0 to 1709
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nom_lieu   1710 non-null   object
#  1   desc_lieu  1710 non-null   object
#  2   type_lieu  1710 non-null   object
#  3   list_lieu  1710 non-null   object
#  4   placename  1710 non-null   object
#  5   label      1710 non-null   object
#  6   nombre     1710 non-null   object
#  7   variantes  236 non-null    object
#  8   nombrehoy  190 non-null    object
#  9   categoria  1710 non-null   object
#  10  pais       1710 non-null   object
#  11  lat        1710 non-null   float64
#  12  lon        1710 non-null   float64
#  13  fuente_ID  1710 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 200.4+ KB
# None
